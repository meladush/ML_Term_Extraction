# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_json('/content/drive/MyDrive/ML_Data/term_labeled_texts_val.json')
df.head()
# Out:
#                                       tokenized_text  \
# 0  [АНАЛИЗ, ЛЕКСИКО‐СЕМАНТИЧЕСКИХ, ОСОБЕННОСТЕЙ, ...
# 1  [ИСПОЛЬЗОВАНИЕ, МЕТОДА, УСЛОВНЫХ, СЛУЧАЙНЫХ, П...
# 2  [МНОГОЗНАЧНОСТЬ, КАК, ПРИКЛАДНАЯ, ПРОБЛЕМА, :,...
# 3  [ОПИСАНИЕ, ФРАГМЕНТОВ, С, ПРЯМОЙ, РЕЧЬЮ, В, ПО...
# 4  [ГЕНЕРАЦИЯ, ШАБЛОНОВ, ОЦЕНОЧНЫХ, ВЫРАЖЕНИЙ, НА...
#
#                                         token_labels  \
# 0  [O, B, E, B, E, O, O, O, O, O, O, O, O, O, O, ...
# 1  [O, B, I, I, E, O, O, O, O, B, E, O, O, O, B, ...
# 2  [S, O, O, O, O, B, I, I, E, O, B, I, I, E, O, ...
# 3  [O, O, O, B, E, O, B, E, B, E, O, O, O, O, O, ...
# 4  [S, S, B, E, O, O, B, E, O, O, O, O, O, B, E, ...
#
#                                            new_terms
# 0  [ЛЕКСИКО‐СЕМАНТИЧЕСКИХ ОСОБЕННОСТЕЙ, РЕГИОНАЛЬ...
# 1  [МЕТОДА УСЛОВНЫХ СЛУЧАЙНЫХ ПОЛЕЙ, РУССКОМ ЯЗЫК...
# 2  [МНОГОЗНАЧНОСТЬ, ЛЕКСИКО-СЕМАНТИЧЕСКАЯ РАЗМЕТК...
# 3  [ПРЯМОЙ РЕЧЬЮ, ПОВЕСТВОВАТЕЛЬНЫХ КНИГАХ, ЕВРЕЙ...
# 4  [ГЕНЕРАЦИЯ, ШАБЛОНОВ, ОЦЕНОЧНЫХ ВЫРАЖЕНИЙ, НЕР...

# %%
from transformers import TokenClassificationPipeline, AutoTokenizer, AutoModelForTokenClassification

# %%
tokenizer_term = AutoTokenizer.from_pretrained("Mathnub/ruDistilBert-base-sberquad")

# %%
def postprocess_output(output):

  id2tag = {0: 'O', 1: 'S', 2: 'B', 3: 'I', 4: 'E'}

  string = ''
  tags = []
  last_token_end = 0

  for token in output:
    # сначала обработаем тег
    if '_' in token['entity']:
      tag = id2tag[int(token['entity'].split('_')[1])]
    else:
      tag = token['entity']

    if token['word'][0] != '#':
      # если токен - или начало слова, или полное слово
      if last_token_end != token['start']:
        string += ' '

      string += token['word']
      tags.append(tag)

    else:
      # если токен - середина слова или конец
      string += token['word'].replace('#', '')

    last_token_end = token['end']

  return list(zip(string.split(), tags))

# %%
checkpoint = '/content/drive/MyDrive/ML/Project_Terminology_2/Model_Term_RuDistilBert' # модель училась 50 эпох

# %%
model_term = AutoModelForTokenClassification.from_pretrained(checkpoint)

# %%
termbert = TokenClassificationPipeline(model=model_term, tokenizer=tokenizer_term, task="term")

# %%
postprocess_output(termbert('В данной статье описываются основные принципы работы синтаксического парсера русского языка LPaRus , разработанного на основе лингвистических технологий компании Megaputer Intelligence .'))
# Out:
# [('В', 'O'),
#  ('данной', 'O'),
#  ('статье', 'O'),
#  ('описываются', 'O'),
#  ('основные', 'O'),
#  ('принципы', 'O'),
#  ('работы', 'O'),
#  ('синтаксического', 'B'),
#  ('парсера', 'E'),
#  ('русского', 'B'),
#  ('языка', 'E'),
#  ('LPaRus', 'O'),
#  (',', 'O'),
#  ('разработанного', 'O'),
#  ('на', 'O'),
#  ('основе', 'O'),
#  ('лингвистических', 'B'),
#  ('технологий', 'E'),
#  ('компании', 'O'),
#  ('Megaputer', 'O'),
#  ('Intelligence', 'O'),
#  ('.', 'O')]

# %%
def get_predicted_labels(x):

  labels_pred = []

  text = ' '.join(x['tokenized_text'])
  output = postprocess_output(termbert(text))
  tokens = [i[1] for i in output]
  for i in tokens:
    labels_pred.append(i)

  return labels_pred

# %%
df['pred_labels'] = df.apply(get_predicted_labels, axis=1)

# %%
df.head()
# Out:
#                                       tokenized_text  \
# 0  [АНАЛИЗ, ЛЕКСИКО‐СЕМАНТИЧЕСКИХ, ОСОБЕННОСТЕЙ, ...
# 1  [ИСПОЛЬЗОВАНИЕ, МЕТОДА, УСЛОВНЫХ, СЛУЧАЙНЫХ, П...
# 2  [МНОГОЗНАЧНОСТЬ, КАК, ПРИКЛАДНАЯ, ПРОБЛЕМА, :,...
# 3  [ОПИСАНИЕ, ФРАГМЕНТОВ, С, ПРЯМОЙ, РЕЧЬЮ, В, ПО...
# 4  [ГЕНЕРАЦИЯ, ШАБЛОНОВ, ОЦЕНОЧНЫХ, ВЫРАЖЕНИЙ, НА...
#
#                                         token_labels  \
# 0  [O, B, E, B, E, O, O, O, O, O, O, O, O, O, O, ...
# 1  [O, B, I, I, E, O, O, O, O, B, E, O, O, O, B, ...
# 2  [S, O, O, O, O, B, I, I, E, O, B, I, I, E, O, ...
# 3  [O, O, O, B, E, O, B, E, B, E, O, O, O, O, O, ...
# 4  [S, S, B, E, O, O, B, E, O, O, O, O, O, B, E, ...
#
#                                            new_terms  \
# 0  [ЛЕКСИКО‐СЕМАНТИЧЕСКИХ ОСОБЕННОСТЕЙ, РЕГИОНАЛЬ...
# 1  [МЕТОДА УСЛОВНЫХ СЛУЧАЙНЫХ ПОЛЕЙ, РУССКОМ ЯЗЫК...
# 2  [МНОГОЗНАЧНОСТЬ, ЛЕКСИКО-СЕМАНТИЧЕСКАЯ РАЗМЕТК...
# 3  [ПРЯМОЙ РЕЧЬЮ, ПОВЕСТВОВАТЕЛЬНЫХ КНИГАХ, ЕВРЕЙ...
# 4  [ГЕНЕРАЦИЯ, ШАБЛОНОВ, ОЦЕНОЧНЫХ ВЫРАЖЕНИЙ, НЕР...
#
#                                          pred_labels
# 0  [O, S, O, B, E, B, E, O, O, O, O, B, I, E, O, ...
# 1  [O, B, B, I, E, O, B, E, O, B, E, O, O, O, O, ...
# 2  [S, O, B, E, O, B, I, I, E, O, B, I, I, E, O, ...
# 3  [O, B, I, I, E, O, B, I, I, E, O, O, O, O, S, ...
# 4  [S, B, I, E, O, O, B, E, O, O, O, O, O, B, E, ...

# %%
def len_check(x):

  return len(x['token_labels']) == len(x['pred_labels'])

# %%
df['len_check'] = df.apply(len_check, axis=1)

# %%
df['len_check'].value_counts()
# Out:
# len_check
# True     48
# False     2
# Name: count, dtype: int64

# %%
df = df[df['len_check'] == True].reset_index(drop=True)

# %%
df
# Out:
#                                        tokenized_text  \
# 0   [ИСПОЛЬЗОВАНИЕ, МЕТОДА, УСЛОВНЫХ, СЛУЧАЙНЫХ, П...
# 1   [МНОГОЗНАЧНОСТЬ, КАК, ПРИКЛАДНАЯ, ПРОБЛЕМА, :,...
# 2   [ОПИСАНИЕ, ФРАГМЕНТОВ, С, ПРЯМОЙ, РЕЧЬЮ, В, ПО...
# 3   [ГЕНЕРАЦИЯ, ШАБЛОНОВ, ОЦЕНОЧНЫХ, ВЫРАЖЕНИЙ, НА...
# 4   [ФРАЗОВАЯ, АКЦЕНТУАЦИЯ, В, СЛОЖНЫХ, ПРЕДЛОЖЕНИ...
# 5   [Лексико, -, грамматические, базы, данных, и, ...
# 6   [ЛЕКСИКАЛИЗОВАННАЯ, ПРОСОДИЯ, И, ПОЛИСЕМИЯ, ДИ...
# 7   [ИНТОНАЦИЯ, РЕЧЕВЫХ, ДЕЙСТВИЙ, ., МНОГОЗНАЧНОС...
# 8   [Особенности, подготовки, терминов, для, русск...
# 9   [МЕСТО, МЕЖЪЯЗЫКОВОЙ, ДЕВИАТОЛОГИИ, В, ОБЩЕЙ, ...
# 10  [КАРТА, СЛОВ, :, ПЕРЕОСМЫСЛЕНИЕ, ПОДХОДА, К, С...
# 11  [КОМПЛЕКСНАЯ, ТЕХНОЛОГИЯ, АВТОМАТИЧЕСКОЙ, КЛАС...
# 12  [ОПРЕДЕЛЕНИЕ, СЕМАНТИЧЕСКОЙ, БЛИЗОСТИ, РУССКО...
# 13  [ВАРИАНТЫ, РОДОВОЙ, ПРИНАДЛЕЖНОСТИ, В, ГРУППЕ,...
# 14  [КАКИЕ, ФАКТОРЫ, ВЛИЯЮТ, НА, СТРУКТУРУ, ДИСКУР...
# 15  [Программа, выделения, русских, индивидуализир...
# 16  [О, СЕМАНТИЧЕСКОМ, ПОДХОДЕ, К, КЛАССИФИКАЦИИ, ...
# 17  [КОРПУС, ТЕКСТОВ, –, НОВЫЙ, ТИП, СЛОВЕСНОГО, Е...
# 18  [Разметка, кореференции, на, синтаксически, ан...
# 19  [ПРАГМАТИЧЕСКИЕ, АСПЕКТЫ, СОЗДАНИЯ, СЕМАНТИЧЕС...
# 20  [АВТОМАТИЗАЦИЯ, ФОРМИРОВАНИЯ, ИНДИКАТОРНЫХ, СЛ...
# 21  [ПРЕДИКАТИВЫ, СО, ЗНАЧЕНИЕМ, НЕОБХОДИМОСТИ, :,...
# 22  [КОРПУС, ПАРАЛЛЕЛЬНЫХ, ТЕКСТОВ, В, АНАЛИЗЕ, СО...
# 23  [НАМЕК, КАК, СПОСОБ, КОСВЕННОЙ, ПЕРЕДАЧИ, СМЫС...
# 24  [Cемантические, источники, уступительности, Ус...
# 25  [СЕМАНТИКА, БЕЗ, СИНТАКСИСА, Традиционная, фор...
# 26  [ИДЕНТИФИКАЦИЯ, ПОСЕССИВНЫХ, СВЯЗЕЙ, ДЛЯ, ИМЕН...
# 27  [Морфологические, модули, на, сайте, www.aot.r...
# 28  [«, НАИВНАЯ, МЕХАНИКА, », В, ЯЗЫКЕ, И, ОНТОЛОГ...
# 29  [Влияние, паузы, хезитации, на, понимание, син...
# 30  [Электронный, семантический, словарь, глагольн...
# 31  [ОСНОВНЫЕ, КОГНИТИВНО, -, КОММУНИКАТИВНЫЕ, ТИП...
# 32  [Некоторые, проблемы, семантики, словосложения...
# 33  [Опыт, систематизации, знаний, и, интернет, -,...
# 34  [КОРРЕКЦИЯ, СМЫСЛОВЫХ, ОТНОШЕНИЙ, КАК, ЭТАП, С...
# 35  [Выявление, ролевых, функций, лиц, на, основе,...
# 36  [О, МЕСТЕ, СЕМАНТИЧЕСКИХ, РОЛЕЙ, ИМЕН, ПРИЛАГА...
# 37  [К, СЕМАНТИКЕ, РУССКОГО, ВИДА, :, МОМЕНТ, НАБЛ...
# 38  [СИНТАКСИЧЕСКИЙ, ПАРСЕР, РУССКОГО, ЯЗЫКА, LPA...
# 39  [ЭФФЕКТИВНОСТЬ, ПРИЗНАКОВ, ДЛЯ, АНАЛИЗА, СЛОЖН...
# 40  [О, «, НЕНОМИНАТИВНЫХ, », ЭЛЕКТРОННЫХ, СЛОВАРЯ...
# 41  [О, НЕКОТОРЫХ, СЛУЧАЯХ, ВЗАИМОЗАМЕНЯЕМОСТИ, ГЛ...
# 42  [ПОЭТИЧЕСКИЙ, ПОДКОРПУС, НАЦИОНАЛЬНОГО, КОРПУС...
# 43  [О, языке, отношений, для, формального, описан...
# 44  [АВТОМАТИЧЕСКОЕ, ОПРЕДЕЛЕНИЕ, ТЕМАТИКИ, БОЛЬШО...
# 45  [ДИСТРИБУЦИЯ, РУССКИХ, ОТНОСИТЕЛЬНЫХ, МЕСТОИМЕ...
# 46  [СТРУКТУРА, ЭМОЦИОНАЛЬНО, -, ЭКСПРЕССИВНОГО, К...
# 47  [СЕМАНТИКО, -, СИНТАКСИЧЕСКИЙ, АНАЛИЗАТОР, SEM...
#
#                                          token_labels  \
# 0   [O, B, I, I, E, O, O, O, O, B, E, O, O, O, B, ...
# 1   [S, O, O, O, O, B, I, I, E, O, B, I, I, E, O, ...
# 2   [O, O, O, B, E, O, B, E, B, E, O, O, O, O, O, ...
# 3   [S, S, B, E, O, O, B, E, O, O, O, O, O, B, E, ...
# 4   [B, E, O, B, E, O, B, E, O, B, E, O, O, O, B, ...
# 5   [B, I, I, I, E, O, O, O, O, B, I, E, O, O, S, ...
# 6   [B, E, O, S, B, E, O, O, O, B, I, E, O, O, B, ...
# 7   [S, B, E, O, S, O, B, E, O, O, O, B, I, I, I, ...
# 8   [O, O, S, O, O, O, O, S, O, B, E, O, O, O, O, ...
# 9   [O, B, E, O, B, I, E, O, S, O, O, O, S, O, O, ...
# 10  [B, E, O, O, O, O, O, B, I, E, O, O, O, O, O, ...
# 11  [O, O, B, I, E, O, O, O, O, O, O, O, O, O, B, ...
# 12  [O, B, E, O, O, O, O, O, B, E, O, O, O, O, O, ...
# 13  [S, O, O, O, O, B, E, O, O, O, B, E, O, O, B, ...
# 14  [O, O, O, O, O, S, O, O, O, O, S, O, O, O, B, ...
# 15  [S, O, O, B, I, E, O, O, O, O, S, S, O, O, O, ...
# 16  [O, B, E, O, O, B, E, O, O, O, O, O, B, E, B, ...
# 17  [S, O, O, O, O, O, O, O, O, O, O, O, S, O, O, ...
# 18  [S, S, O, B, I, E, O, O, O, O, O, B, E, S, O, ...
# 19  [B, E, O, B, E, S, B, E, O, O, O, O, B, E, O, ...
# 20  [B, I, I, E, O, O, O, O, O, B, I, I, E, O, O, ...
# 21  [S, O, S, O, O, S, O, S, O, B, E, O, O, O, B, ...
# 22  [S, O, O, O, O, O, O, O, O, B, E, O, O, O, O, ...
# 23  [O, O, O, B, I, E, O, O, S, O, B, E, O, O, O, ...
# 24  [B, E, O, O, O, B, E, O, O, O, S, O, B, E, O, ...
# 25  [S, O, S, O, B, E, S, O, O, O, O, O, B, E, O, ...
# 26  [B, I, E, O, S, O, O, B, E, O, O, B, E, O, O, ...
# 27  [B, E, O, S, O, O, S, O, B, E, O, S, O, O, O, ...
# 28  [O, O, S, O, O, S, O, S, O, O, O, O, O, O, O, ...
# 29  [O, B, E, O, O, B, I, E, S, B, E, O, O, B, E, ...
# 30  [B, I, E, B, E, O, O, O, O, O, O, O, O, B, I, ...
# 31  [O, B, I, I, I, I, E, O, B, E, O, S, O, O, O, ...
# 32  [O, O, S, S, O, O, O, O, B, E, O, O, B, E, O, ...
# 33  [O, O, O, O, B, I, E, O, B, E, O, B, E, O, O, ...
# 34  [B, I, E, O, O, B, E, O, O, O, B, E, O, O, O, ...
# 35  [B, I, I, E, O, O, B, E, O, B, I, I, I, E, O, ...
# 36  [O, O, B, E, B, E, O, S, O, B, I, I, E, B, E, ...
# 37  [O, S, O, S, O, O, O, O, B, E, O, B, E, B, E, ...
# 38  [B, E, B, E, O, O, O, O, O, O, O, O, O, O, O, ...
# 39  [O, S, O, B, E, B, E, O, B, E, O, O, O, O, B, ...
# 40  [O, B, I, I, I, E, O, O, O, O, B, E, O, O, B, ...
# 41  [O, O, O, O, S, O, S, O, O, O, O, O, O, S, O, ...
# 42  [B, E, B, I, I, E, O, B, E, O, O, B, E, S, O, ...
# 43  [O, S, O, O, B, I, I, E, O, B, E, O, O, O, O, ...
# 44  [B, I, E, O, B, I, E, O, O, B, I, I, E, O, O, ...
# 45  [S, O, B, E, O, O, O, O, O, O, O, O, O, O, O, ...
# 46  [O, B, I, I, E, O, S, B, E, O, O, O, O, O, B, ...
# 47  [B, I, I, E, O, O, O, O, B, I, I, E, O, O, O, ...
#
#                                             new_terms  \
# 0   [МЕТОДА УСЛОВНЫХ СЛУЧАЙНЫХ ПОЛЕЙ, РУССКОМ ЯЗЫК...
# 1   [МНОГОЗНАЧНОСТЬ, ЛЕКСИКО-СЕМАНТИЧЕСКАЯ РАЗМЕТК...
# 2   [ПРЯМОЙ РЕЧЬЮ, ПОВЕСТВОВАТЕЛЬНЫХ КНИГАХ, ЕВРЕЙ...
# 3   [ГЕНЕРАЦИЯ, ШАБЛОНОВ, ОЦЕНОЧНЫХ ВЫРАЖЕНИЙ, НЕР...
# 4   [ФРАЗОВАЯ АКЦЕНТУАЦИЯ, СЛОЖНЫХ ПРЕДЛОЖЕНИЯХ, П...
# 5   [Лексико-грамматические базы данных, диалектны...
# 6   [ЛЕКСИКАЛИЗОВАННАЯ ПРОСОДИЯ, ПОЛИСЕМИЯ, ДИСКУР...
# 7   [ИНТОНАЦИЯ, РЕЧЕВЫХ ДЕЙСТВИЙ, МНОГОЗНАЧНОСТЬ, ...
# 8   [терминов, тезауруса, компьютерной лингвистике...
# 9   [МЕЖЪЯЗЫКОВОЙ ДЕВИАТОЛОГИИ, ОБЩЕЙ ТЕОРИИ ОШИБО...
# 10  [КАРТА СЛОВ, ОНЛАЙН-СЛОВАРЕЙ, словарной инфо...
# 11  [АВТОМАТИЧЕСКОЙ КЛАССИФИКАЦИИ ТЕКСТОВ, приклад...
# 12  [СЕМАНТИЧЕСКОЙ БЛИЗОСТИ, DKPRO SIMILARITY, оц...
# 13  [ВАРИАНТЫ, ИМЕН СУЩЕСТВИТЕЛЬНЫХ, РУССКОМ ЯЗЫКЕ...
# 14  [ДИСКУРСА, переводов, русский язык, дискурса, ...
# 15  [Программа, индивидуализированных именных груп...
# 16  [СЕМАНТИЧЕСКОМ ПОДХОДЕ, СКАЗОЧНЫХ ТЕКСТОВ, сем...
# 17  [КОРПУС, корпусов, корпусной лингвистики, опре...
# 18  [Разметка, кореференции, синтаксически аннотир...
# 19  [ПРАГМАТИЧЕСКИЕ АСПЕКТЫ, СЕМАНТИЧЕСКОГО СЛОВАР...
# 20  [АВТОМАТИЗАЦИЯ ФОРМИРОВАНИЯ ИНДИКАТОРНЫХ СЛОВА...
# 21  [ПРЕДИКАТИВЫ, ЗНАЧЕНИЕМ, СТАТИСТИКА, СЕМАНТИКА...
# 22  [КОРПУС, ЗАЛОГОВЫХ ФОРМ, параллельного корпуса...
# 23  [КОСВЕННОЙ ПЕРЕДАЧИ СМЫСЛА, семантические, пра...
# 24  [Cемантические источники, сложный смысл, слова...
# 25  [СЕМАНТИКА, СИНТАКСИСА, формальная семантика, ...
# 26  [ИДЕНТИФИКАЦИЯ ПОСЕССИВНЫХ СВЯЗЕЙ, ИМЕН, ЧАСТИ...
# 27  [Морфологические модули, сайте, модули, морфол...
# 28  [МЕХАНИКА, ЯЗЫКЕ, ОНТОЛОГИИ, лексики, механику...
# 29  [паузы хезитации, синтаксической структуры пре...
# 30  [Электронный семантический словарь, глагольных...
# 31  [КОГНИТИВНО-КОММУНИКАТИВНЫЕ ТИПЫ ОБЩИХ ВОПРОСО...
# 32  [семантики, словосложения, семантических отнош...
# 33  [интернет-ресурсов, портала знаний, компьютерн...
# 34  [КОРРЕКЦИЯ СМЫСЛОВЫХ ОТНОШЕНИЙ, СЕМАНТИЧЕСКОГО...
# 35  [Выявление ролевых функций лиц, структур знани...
# 36  [СЕМАНТИЧЕСКИХ РОЛЕЙ, ИМЕН ПРИЛАГАТЕЛЬНЫХ, ГРА...
# 37  [СЕМАНТИКЕ, ВИДА, ДИСКУРСИВНЫЙ КОНТЕКСТ, внутр...
# 38  [СИНТАКСИЧЕСКИЙ ПАРСЕР, РУССКОГО ЯЗЫКА, синта...
# 39  [ПРИЗНАКОВ, АНАЛИЗА СЛОЖНОСТИ, АКАДЕМИЧЕСКИХ Т...
# 40  [«НЕНОМИНАТИВНЫХ» ЭЛЕКТРОННЫХ СЛОВАРЯХ, электр...
# 41  [ГЛАГОЛОВ, СЕМАНТИКОЙ, славянских, германских ...
# 42  [ПОЭТИЧЕСКИЙ ПОДКОРПУС, НАЦИОНАЛЬНОГО КОРПУСА ...
# 43  [языке, формального описания предметной област...
# 44  [АВТОМАТИЧЕСКОЕ ОПРЕДЕЛЕНИЕ ТЕМАТИКИ, НЕОБРАБО...
# 45  [ДИСТРИБУЦИЯ, ОТНОСИТЕЛЬНЫХ МЕСТОИМЕНИЙ, место...
# 46  [ЭМОЦИОНАЛЬНО-ЭКСПРЕССИВНОГО КОМПОНЕНТА, ТЕЗАУ...
# 47  [СЕМАНТИКО-СИНТАКСИЧЕСКИЙ АНАЛИЗАТОР, семантик...
#
#                                           pred_labels  len_check
# 0   [O, B, B, I, E, O, B, E, O, B, E, O, O, O, O, ...       True
# 1   [S, O, B, E, O, B, I, I, E, O, B, I, I, E, O, ...       True
# 2   [O, B, I, I, E, O, B, I, I, E, O, O, O, O, S, ...       True
# 3   [S, B, I, E, O, O, B, E, O, O, O, O, O, B, E, ...       True
# 4   [B, E, O, B, E, O, B, E, O, B, E, O, O, O, B, ...       True
# 5   [B, I, I, I, E, O, O, O, O, B, I, E, O, O, B, ...       True
# 6   [B, E, O, O, B, E, O, O, O, O, O, S, O, O, B, ...       True
# 7   [S, B, E, O, S, O, O, S, O, O, O, B, O, O, O, ...       True
# 8   [O, O, S, O, O, O, O, S, O, B, E, O, O, O, O, ...       True
# 9   [O, B, E, O, O, B, O, O, S, O, O, O, S, O, O, ...       True
# 10  [O, O, O, O, O, O, B, O, O, O, O, O, O, O, O, ...       True
# 11  [B, E, B, I, E, O, O, O, O, O, O, O, O, O, B, ...       True
# 12  [O, O, S, B, E, O, O, S, O, O, O, O, O, O, O, ...       True
# 13  [S, I, E, O, O, B, B, I, E, O, B, E, O, O, B, ...       True
# 14  [O, S, S, O, O, S, O, O, O, O, S, B, E, O, B, ...       True
# 15  [S, O, O, B, I, E, O, O, O, O, O, O, O, O, O, ...       True
# 16  [O, B, E, O, S, B, E, O, O, O, O, O, B, E, B, ...       True
# 17  [S, O, O, O, O, B, E, O, S, O, O, O, B, E, O, ...       True
# 18  [S, S, O, B, I, E, O, O, O, O, O, O, S, S, O, ...       True
# 19  [B, E, O, B, E, O, B, E, O, O, O, B, I, E, O, ...       True
# 20  [O, O, B, E, O, O, O, O, O, O, I, I, E, O, O, ...       True
# 21  [S, O, S, O, O, S, O, S, O, B, E, O, O, O, B, ...       True
# 22  [S, B, E, O, O, O, O, O, B, B, E, O, O, O, O, ...       True
# 23  [O, O, O, B, I, E, O, O, S, O, B, E, S, O, O, ...       True
# 24  [O, O, S, S, O, O, O, O, O, O, S, O, B, E, O, ...       True
# 25  [S, O, S, O, B, E, S, O, O, O, O, O, B, E, O, ...       True
# 26  [O, B, E, O, S, O, O, B, E, O, O, B, E, O, O, ...       True
# 27  [B, E, O, O, O, O, O, O, O, O, S, O, B, E, O, ...       True
# 28  [O, O, O, O, O, S, O, S, O, O, O, O, O, B, E, ...       True
# 29  [O, S, S, O, O, B, I, E, S, B, E, O, O, S, E, ...       True
# 30  [B, I, E, B, E, O, O, O, O, O, O, O, O, B, I, ...       True
# 31  [B, B, I, I, E, O, S, O, B, E, B, E, O, O, O, ...       True
# 32  [O, O, S, S, O, O, O, O, B, E, O, B, I, E, O, ...       True
# 33  [O, O, O, O, B, B, E, O, B, E, O, B, E, O, O, ...       True
# 34  [S, I, E, O, O, B, E, O, O, O, B, E, O, O, O, ...       True
# 35  [O, B, E, O, O, O, B, E, O, B, I, I, I, E, O, ...       True
# 36  [O, O, B, I, B, E, O, S, O, B, I, I, E, B, E, ...       True
# 37  [O, S, O, S, O, S, S, O, B, E, O, B, E, B, E, ...       True
# 38  [O, O, B, I, I, E, O, O, O, O, O, O, O, O, O, ...       True
# 39  [O, S, O, O, B, I, E, O, B, E, O, O, O, O, O, ...       True
# 40  [O, B, I, I, I, E, O, O, O, O, B, E, O, O, B, ...       True
# 41  [O, B, E, O, S, O, B, E, O, S, O, O, O, S, O, ...       True
# 42  [B, E, B, E, B, E, O, B, E, O, O, B, E, O, O, ...       True
# 43  [O, S, O, O, O, O, B, E, O, B, E, O, O, O, O, ...       True
# 44  [B, I, E, O, I, I, E, O, O, B, I, I, E, O, O, ...       True
# 45  [S, O, B, E, O, O, O, O, O, O, O, O, O, S, O, ...       True
# 46  [O, B, I, I, E, O, S, B, E, O, O, O, O, O, B, ...       True
# 47  [B, I, I, E, O, O, O, O, B, I, I, E, O, O, O, ...       True

# %%
labels_pred = []

for i in range(48):
  for n in df['pred_labels'][i]:
    labels_pred.append(n)

# %%
len(labels_pred)
# Out:
# 4273

# %%
labels_true = []

for i in range(48):
  for i in df['token_labels'][i]:
    labels_true.append(i)

# %%
len(labels_true)
# Out:
# 4273

# %%
import numpy

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
y_true = numpy.array(labels_true)
y_pred = numpy.array(labels_pred)

# %%
y_true.shape
# Out:
# (4273,)

# %%
y_pred.shape
# Out:
# (4273,)

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.68      0.69      0.69       409
#            E       0.74      0.74      0.74       409
#            I       0.55      0.56      0.56       156
#            O       0.92      0.91      0.92      2979
#            S       0.65      0.67      0.66       320
#
#     accuracy                           0.85      4273
#    macro avg       0.71      0.72      0.71      4273
# weighted avg       0.85      0.85      0.85      4273

# %%
ConfusionMatrixDisplay.from_predictions(y_true, y_pred)
plt.show()
